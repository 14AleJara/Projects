# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/constanzavargasmier/Desktop/Ale/DATASETS/Transactions.csv')

# %%
df2 = pd.read_csv(r'/Users/constanzavargasmier/Desktop/Ale/DATASETS/Swift Codes.csv')

# %%
df2
# Out:
#                Bank SWIFT code Check Digits
# 0       Lloyds Bank       LOYD           C1
# 1     Barclays Bank       BARC           22
# 2           Halifax       HLFX           22
# 3              HSBC       HBUK           4B
# 4           Natwest       NWBK           2L
# 5         Santander       ABBY           3E
# 6  Data Source Bank       DSBX           12

# %%
df
# Out:
#     Transaction ID  Account Number Sort Code              Bank
# 0             3888        62230725  95-98-82  Data Source Bank
# 1             4746        83172326  42-86-38     Barclays Bank
# 2             5404        34302539  53-28-21     Barclays Bank
# 3             9013        13350031  93-87-71           Natwest
# 4             2535        68745993  57-14-32     Barclays Bank
# ..             ...             ...       ...               ...
# 95            9373        44568613  24-15-12              HSBC
# 96            2021        72261023  59-17-51       Lloyds Bank
# 97            6764        10570182  29-72-39  Data Source Bank
# 98            3286        47326725  21-85-30           Halifax
# 99            7423        75616805  49-31-26           Halifax
#
# [100 rows x 4 columns]

# %%
df['Sort Code'] = df['Sort Code'].str.replace('[^0-9]','')
# Out:
# /var/folders/tm/436vrc9x7cl5f63h3zm7tmzr0000gn/T/ipykernel_18012/3701964475.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Sort Code'] = df['Sort Code'].str.replace('[^0-9]','')

# %%
df
# Out:
#     Transaction ID  Account Number Sort Code              Bank
# 0             3888        62230725    959882  Data Source Bank
# 1             4746        83172326    428638     Barclays Bank
# 2             5404        34302539    532821     Barclays Bank
# 3             9013        13350031    938771           Natwest
# 4             2535        68745993    571432     Barclays Bank
# ..             ...             ...       ...               ...
# 95            9373        44568613    241512              HSBC
# 96            2021        72261023    591751       Lloyds Bank
# 97            6764        10570182    297239  Data Source Bank
# 98            3286        47326725    218530           Halifax
# 99            7423        75616805    493126           Halifax
#
# [100 rows x 4 columns]

# %%
df3 = df.merge(df2)

# %%
df3
# Out:
#     Transaction ID  Account Number Sort Code              Bank SWIFT code  \
# 0             3888        62230725    959882  Data Source Bank       DSBX
# 1             7086        56630552    597744  Data Source Bank       DSBX
# 2             1314        71210735    618579  Data Source Bank       DSBX
# 3             1493        12193988    865442  Data Source Bank       DSBX
# 4             1952        53786334    212754  Data Source Bank       DSBX
# ..             ...             ...       ...               ...        ...
# 95            6054        47199472    968854       Lloyds Bank       LOYD
# 96            5773        82021377    438613       Lloyds Bank       LOYD
# 97            7485        63007765    634617       Lloyds Bank       LOYD
# 98            8813        83475180    635891       Lloyds Bank       LOYD
# 99            2021        72261023    591751       Lloyds Bank       LOYD
#
#    Check Digits
# 0            12
# 1            12
# 2            12
# ...

# %%
df3['Country_Code'] = 'GB'
df3
# Out:
#     Transaction ID  Account Number Sort Code              Bank SWIFT code  \
# 0             3888        62230725    959882  Data Source Bank       DSBX
# 1             7086        56630552    597744  Data Source Bank       DSBX
# 2             1314        71210735    618579  Data Source Bank       DSBX
# 3             1493        12193988    865442  Data Source Bank       DSBX
# 4             1952        53786334    212754  Data Source Bank       DSBX
# ..             ...             ...       ...               ...        ...
# 95            6054        47199472    968854       Lloyds Bank       LOYD
# 96            5773        82021377    438613       Lloyds Bank       LOYD
# 97            7485        63007765    634617       Lloyds Bank       LOYD
# 98            8813        83475180    635891       Lloyds Bank       LOYD
# 99            2021        72261023    591751       Lloyds Bank       LOYD
#
#    Check Digits Country_Code
# 0            12           GB
# ...

# %%
df3['IBAN'] = df3['Country_Code'] + df3['Check Digits'].astype(str) + df3['Sort Code'].astype(str) + df3['Account Number'].astype(str)

# %%
df3
# Out:
#     Transaction ID  Account Number Sort Code              Bank SWIFT code  \
# 0             3888        62230725    959882  Data Source Bank       DSBX
# 1             7086        56630552    597744  Data Source Bank       DSBX
# 2             1314        71210735    618579  Data Source Bank       DSBX
# 3             1493        12193988    865442  Data Source Bank       DSBX
# 4             1952        53786334    212754  Data Source Bank       DSBX
# ..             ...             ...       ...               ...        ...
# 95            6054        47199472    968854       Lloyds Bank       LOYD
# 96            5773        82021377    438613       Lloyds Bank       LOYD
# 97            7485        63007765    634617       Lloyds Bank       LOYD
# 98            8813        83475180    635891       Lloyds Bank       LOYD
# 99            2021        72261023    591751       Lloyds Bank       LOYD
#
#    Check Digits Country_Code                IBAN
# ...

# %%
df4 = df3

# %%
df4
# Out:
#     Transaction ID  Account Number Sort Code              Bank SWIFT code  \
# 0             3888        62230725    959882  Data Source Bank       DSBX
# 1             7086        56630552    597744  Data Source Bank       DSBX
# 2             1314        71210735    618579  Data Source Bank       DSBX
# 3             1493        12193988    865442  Data Source Bank       DSBX
# 4             1952        53786334    212754  Data Source Bank       DSBX
# ..             ...             ...       ...               ...        ...
# 95            6054        47199472    968854       Lloyds Bank       LOYD
# 96            5773        82021377    438613       Lloyds Bank       LOYD
# 97            7485        63007765    634617       Lloyds Bank       LOYD
# 98            8813        83475180    635891       Lloyds Bank       LOYD
# 99            2021        72261023    591751       Lloyds Bank       LOYD
#
#    Check Digits Country_Code                IBAN
# ...

# %%
df4 = df4.drop(columns = ['Account Number','Sort Code','Bank','SWIFT code','Check Digits','Country_Code'])

# %%
df4
# Out:
#     Transaction ID                IBAN
# 0             3888  GB1295988262230725
# 1             7086  GB1259774456630552
# 2             1314  GB1261857971210735
# 3             1493  GB1286544212193988
# 4             1952  GB1221275453786334
# ..             ...                 ...
# 95            6054  GBC196885447199472
# 96            5773  GBC143861382021377
# 97            7485  GBC163461763007765
# 98            8813  GBC163589183475180
# 99            2021  GBC159175172261023
#
# [100 rows x 2 columns]
